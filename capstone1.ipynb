# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/gtsrb-german-traffic-sign/Meta.csv
# /kaggle/input/gtsrb-german-traffic-sign/Train.csv
# /kaggle/input/gtsrb-german-traffic-sign/Test.csv
# /kaggle/input/gtsrb-german-traffic-sign/Meta/37.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/35.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/11.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/31.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/4.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/40.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/33.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/9.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/.~lock.ClassesInformation.ods#
# /kaggle/input/gtsrb-german-traffic-sign/Meta/14.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/1.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/39.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/20.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/38.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/2.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/10.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/36.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/18.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/21.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/12.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/28.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/22.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/34.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/41.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/.~lock.ClassesInformationStrong.ods#
# /kaggle/input/gtsrb-german-traffic-sign/Meta/7.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/29.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/17.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/5.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/3.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/16.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/8.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/24.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/32.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/6.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/23.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/15.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/30.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/27.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/13.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/25.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/0.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/19.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/26.png
# /kaggle/input/gtsrb-german-traffic-sign/Meta/42.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/37.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/35.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/11.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/31.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/4.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/40.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/33.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/9.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/.~lock.ClassesInformation.ods#
# /kaggle/input/gtsrb-german-traffic-sign/meta/14.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/1.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/39.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/20.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/38.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/2.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/10.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/36.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/18.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/21.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/12.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/28.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/22.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/34.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/41.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/.~lock.ClassesInformationStrong.ods#
# /kaggle/input/gtsrb-german-traffic-sign/meta/7.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/29.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/17.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/5.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/3.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/16.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/8.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/24.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/32.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/6.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/23.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/15.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/30.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/27.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/13.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/25.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/0.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/19.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/26.png
# /kaggle/input/gtsrb-german-traffic-sign/meta/42.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01301.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02578.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06781.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11396.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00929.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04915.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07470.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08216.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12329.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02630.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03862.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01883.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00704.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03163.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01124.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04159.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01570.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07161.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05717.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03092.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06102.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03663.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10760.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04084.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04216.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02640.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02422.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03434.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02284.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00562.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08028.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02715.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00237.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02606.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03852.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08057.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07814.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02073.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00406.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12204.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01582.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10188.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05084.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06076.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06877.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00448.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11953.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09031.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01686.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00255.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12139.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09393.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00435.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06852.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11572.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07968.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07430.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05130.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02247.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08725.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11070.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00365.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07901.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11927.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06027.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04766.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10107.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05649.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04710.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00105.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09360.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02626.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09210.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06426.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01574.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03495.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01523.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09510.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12470.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01569.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03895.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01716.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04645.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01735.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03508.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11901.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11711.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10696.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11506.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07874.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04282.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05678.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01829.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00936.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10124.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03289.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06704.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10316.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11246.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00512.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09821.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05316.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04117.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11695.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10106.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04213.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07512.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03041.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06344.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02053.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06996.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04234.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11196.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10496.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09406.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06714.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00869.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00669.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00733.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05220.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00657.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10149.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00033.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01606.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09877.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03899.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02821.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10563.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07102.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07659.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05264.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01081.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06696.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01748.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06772.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08747.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05101.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08522.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11208.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03602.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08035.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01595.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10163.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06363.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04953.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10628.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04849.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01794.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00096.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09757.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11970.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04388.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01550.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02545.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02472.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07723.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05960.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09276.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10272.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09330.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05116.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07354.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00185.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09988.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06521.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01363.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10062.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02199.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10054.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04865.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12356.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04720.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00238.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02000.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05421.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03422.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01742.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01790.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06376.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10493.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06105.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05100.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04090.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03684.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11549.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10759.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12429.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04913.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01774.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09267.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11659.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01979.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02192.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01191.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07739.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00488.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06832.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10104.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01352.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09187.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11822.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06579.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07047.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05874.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01594.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00356.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12381.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01793.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11766.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03747.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00082.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09860.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12490.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07777.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01241.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02362.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02931.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05261.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02176.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00004.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09137.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01820.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01460.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08900.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10626.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05370.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12056.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09573.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08007.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01783.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04289.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02105.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08508.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08407.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07122.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11006.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12412.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07597.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04640.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04122.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04133.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01334.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04777.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05131.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10299.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09035.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12468.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10797.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00305.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09557.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10874.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04103.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02594.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10897.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04944.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07326.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00124.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03378.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09733.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00874.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08527.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02544.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00023.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11251.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01023.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12022.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03814.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02185.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12525.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08780.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01499.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01318.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04596.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07168.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09902.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12032.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10972.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10501.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03938.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10829.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12105.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07299.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03017.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09975.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04187.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10799.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03975.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06557.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11874.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07001.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00723.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00145.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08485.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12004.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00100.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03479.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03790.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05179.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07121.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02241.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08521.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01946.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09935.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08286.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09893.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05814.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04272.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07296.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06793.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07525.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05135.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07046.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02376.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00041.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00080.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08910.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00298.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12034.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12305.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08975.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08671.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04732.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07649.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11322.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03698.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01927.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08420.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03164.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04124.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11457.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01021.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08462.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06126.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00024.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00239.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10597.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04855.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07482.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02352.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11545.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11617.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07841.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01048.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01696.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01689.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04843.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07084.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06279.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00965.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05606.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09178.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01202.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11460.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08251.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06825.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12177.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07683.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11482.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01895.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05068.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05011.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00052.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11780.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10213.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01739.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03630.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07684.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04281.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03024.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06818.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09273.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12348.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01867.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07636.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12508.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01673.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10464.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00173.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05401.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10466.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04755.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09482.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11100.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01036.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07693.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06673.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03016.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10920.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09450.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00468.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07647.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02319.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01741.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11176.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10942.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07959.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00254.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03717.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01813.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06337.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08140.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12261.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10547.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07111.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01537.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11437.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11765.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01071.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12451.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07661.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10713.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01730.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11454.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05077.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04827.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00570.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00280.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02629.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10492.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12267.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09628.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03834.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08362.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00578.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01745.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10167.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07278.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01598.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04742.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00515.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05412.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01614.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06058.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01329.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07805.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03155.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04867.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00242.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03405.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03225.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01171.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08275.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03436.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05775.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05820.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10483.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08777.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09183.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01949.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03547.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07940.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05062.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05631.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03160.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04016.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10431.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01061.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00123.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03377.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04059.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04041.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07487.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00250.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02195.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02508.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02939.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06654.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11884.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11034.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01039.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06791.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11275.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09587.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02887.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01532.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02510.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10481.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07381.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11938.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04595.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01057.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01370.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01379.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09106.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10728.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08730.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07862.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10198.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05785.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08600.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00644.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06420.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06299.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09198.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06637.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03238.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06418.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02688.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04228.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09710.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01988.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09480.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07368.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09215.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08250.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07418.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04409.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07696.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02731.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12516.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07515.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05481.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07207.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05324.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05299.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08565.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07394.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07097.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04586.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03491.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01652.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03606.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08543.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01030.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02675.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04202.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11845.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04569.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04590.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08238.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04337.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06720.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00535.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02074.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02537.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08859.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12385.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05802.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04120.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03915.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03706.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11860.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04873.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02862.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10784.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07522.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00549.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06798.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05694.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01670.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09706.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04457.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11135.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05815.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07319.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06181.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00808.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02075.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05308.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02109.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03143.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03586.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06887.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05231.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06533.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01278.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08342.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01951.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05361.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11213.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08278.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02912.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09958.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12467.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10977.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05507.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11393.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01252.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07846.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05414.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03025.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02952.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11003.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08484.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10345.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12320.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10215.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08514.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05129.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12125.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01518.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09407.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01357.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01477.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02805.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10612.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05617.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10544.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09082.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08974.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00122.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02696.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07740.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02353.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09454.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02025.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04456.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04647.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08547.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07284.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05276.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07083.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07920.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01990.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03557.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05989.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09281.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07052.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01209.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11914.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05713.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08370.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00573.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06755.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02776.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04304.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03700.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04330.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05858.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08013.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12254.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02013.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08617.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01732.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09655.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07013.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02726.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02835.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04787.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08773.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03222.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07341.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04662.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06220.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04319.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12574.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10301.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10841.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08258.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04399.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10016.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05477.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08607.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02512.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12590.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04080.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04780.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05397.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09332.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02831.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11130.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01853.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08866.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02038.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10077.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00409.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02119.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03427.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05160.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03965.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03448.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06057.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10551.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07537.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05250.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04365.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10446.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03144.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11258.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09547.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02026.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08435.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02235.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03184.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09494.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04680.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12235.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07335.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02851.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10830.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07931.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11217.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05047.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03845.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05433.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09556.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04868.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08595.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01729.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09349.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06469.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04693.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07882.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07803.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03022.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05645.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04466.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01801.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06473.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07198.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08328.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04029.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01038.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04918.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04802.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06153.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12554.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08687.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09786.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00973.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04207.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09622.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06486.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05742.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06044.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03179.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01557.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05107.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09810.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06014.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03710.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06298.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02088.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05039.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11369.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10896.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06555.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11621.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11691.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07984.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06700.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09756.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11758.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02452.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12077.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03500.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02411.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07922.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11672.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00787.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00743.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10443.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05868.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09287.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03243.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05728.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02245.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06888.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00572.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07855.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03670.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07721.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07536.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04214.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09968.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02607.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12376.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01856.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04584.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02660.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08513.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04862.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07355.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06402.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08775.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11625.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04832.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01177.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01605.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07967.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12248.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09625.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07212.png
# ...
# /kaggle/input/gtsrb-german-traffic-sign/Test/04071.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03296.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08692.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08466.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00958.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07397.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01885.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11791.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09735.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06742.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09343.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04012.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04464.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01078.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09045.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06529.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01593.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03579.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11064.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09381.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07824.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05066.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09797.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08693.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07452.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06119.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11991.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08770.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00670.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00707.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09290.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08606.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11023.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04210.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05551.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05683.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03804.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08383.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09585.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05136.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03868.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05354.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01174.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11253.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01826.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02400.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07399.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12121.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09998.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07112.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05590.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08843.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10064.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06435.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03510.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01566.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05444.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04515.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09458.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08612.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02784.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06214.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02514.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05967.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03268.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11980.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12456.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09827.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04306.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11595.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10025.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00820.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01449.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12374.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10744.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08523.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07570.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00231.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07993.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04951.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08928.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02965.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01931.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08346.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02331.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09104.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01076.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02040.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06163.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11896.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04093.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02308.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01577.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04026.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00416.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04076.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07639.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05993.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07385.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11977.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08102.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08567.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04650.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01246.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05270.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10476.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10725.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05843.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11987.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05432.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08317.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05948.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08037.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05505.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09073.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00860.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05409.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00412.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04871.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00085.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11870.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07602.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04283.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02388.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05371.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01059.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00551.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04379.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12088.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04106.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02057.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08550.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03105.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03840.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07104.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09100.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07345.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06457.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07420.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08635.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01168.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05496.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03820.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10068.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10503.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12452.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03753.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04073.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10609.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11198.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12419.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04625.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12332.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03393.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10354.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07764.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07823.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09667.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05777.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08490.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06509.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00472.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03819.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10645.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02244.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08985.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04406.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07238.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09335.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06697.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07120.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00053.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06600.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08568.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04238.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08069.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08398.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06395.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00893.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00831.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01599.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01084.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10470.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08888.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02623.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11062.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10835.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11471.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10837.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06856.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05243.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03563.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04446.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05137.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07979.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07551.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08510.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02980.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10640.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05087.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09599.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02267.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01904.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00825.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12380.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06462.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03737.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11931.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01551.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08977.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09319.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01627.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05639.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12122.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07443.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06384.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01201.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03133.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05092.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01214.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00890.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02819.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02890.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07703.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07165.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08178.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02556.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05155.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05525.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06692.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05053.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00732.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11011.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11338.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10407.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04897.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07978.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02408.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04383.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01424.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02827.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08604.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00233.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12038.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03935.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08830.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02285.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02349.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03282.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00872.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07617.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02714.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08906.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01083.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10472.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11923.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03937.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05017.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00908.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07664.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08999.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03158.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06089.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01148.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/05466.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02803.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02590.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01780.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/10617.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03432.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/06459.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01474.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02210.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04445.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04563.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/02739.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/00291.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08944.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/03152.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07818.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09061.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/11733.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/07903.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04741.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/08745.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01982.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/09232.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/04356.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/12060.png
# /kaggle/input/gtsrb-german-traffic-sign/Test/01632.png

# %%
import numpy as np
np.random.seed(1000)

import pandas as pd
import cv2
import keras
import os
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns

os.environ['KERAS_BACKEND'] = 'tensorflow'
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.model_selection import train_test_split
import tensorflow as tf
import pathlib
import matplotlib.pyplot as plt
import os
import numpy as np
import shutil
import tensorflow_hub as hub
import itertools
from six.moves import urllib
from os.path import join, exists
from tensorflow import keras
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, BatchNormalization, Flatten, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger
from tensorflow.keras.applications import VGG16, DenseNet121
from sklearn.metrics import confusion_matrix, classification_report
from PIL import Image
from skimage import transform
from tqdm.notebook import tqdm_notebook
from enum import Enum

num_classes = 43
# Out:
# 2024-08-20 00:10:02.623394: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-20 00:10:02.623592: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-20 00:10:02.787275: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /tmp/ipykernel_222/4072458886.py:26: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
DIR = '/kaggle/input/gtsrb-german-traffic-sign/Train' #Create directory
classes = [i for i in os.listdir(DIR) if '.' not in i]                     #Creating classes
classes
# Out:
# ['7',
#  '17',
#  '19',
#  '22',
#  '2',
#  '35',
#  '23',
#  '10',
#  '5',
#  '36',
#  '20',
#  '27',
#  '41',
#  '39',
#  '32',
#  '25',
#  '42',
#  '8',
#  '38',
#  '12',
#  '0',
#  '31',
#  '34',
#  '18',
#  '28',
#  '16',
#  '13',
#  '26',
#  '15',
#  '3',
#  '1',
#  '30',
#  '14',
#  '4',
#  '9',
#  '21',
#  '40',
#  '6',
#  '11',
#  '37',
#  '33',
#  '29',
#  '24']

# %%
label = []
path = []

for dirname, _,Path in os.walk(DIR):                    
    for Pat in Path:                                 
        if os.path.splitext(Pat)[-1]=='.png':               # If filename contains .png
            label.append(os.path.split(dirname)[-1])        
            path.append(os.path.join(dirname,Pat))    

# Create df
df = pd.DataFrame(columns=['path','label'])
df['path']=path
df['label']=label

# %%
df
# Out:
#                                                     path label
# 0      /kaggle/input/gtsrb-german-traffic-sign/Train/...     7
# 1      /kaggle/input/gtsrb-german-traffic-sign/Train/...     7
# 2      /kaggle/input/gtsrb-german-traffic-sign/Train/...     7
# 3      /kaggle/input/gtsrb-german-traffic-sign/Train/...     7
# 4      /kaggle/input/gtsrb-german-traffic-sign/Train/...     7
# ...                                                  ...   ...
# 39204  /kaggle/input/gtsrb-german-traffic-sign/Train/...    24
# 39205  /kaggle/input/gtsrb-german-traffic-sign/Train/...    24
# 39206  /kaggle/input/gtsrb-german-traffic-sign/Train/...    24
# 39207  /kaggle/input/gtsrb-german-traffic-sign/Train/...    24
# 39208  /kaggle/input/gtsrb-german-traffic-sign/Train/...    24
#
# [39209 rows x 2 columns]

# %%
x = []
for img_path in df['path']:
    if os.path.exists(img_path):
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.resize(img, (32, 32)) # Görüntüyü 32x32 boyutuna küçült
            img = img.astype(np.uint8) # Float64 yerine uint8 kullan
            img = img / 255.0 # Normalize et
            x.append(img)
    else:
        print(f"Görüntü dosyası bulunamadı: {img_path}")

x = np.array(x)
print(x.shape)
# Out:
# (39209, 32, 32, 3)

# %%
y=df['label']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# %%
input_size = (32, 32, 3)
model=Sequential()
model.add(Input(shape=input_size))
model.add(Conv2D(32,kernel_size=(3,3),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128))
model.add(Dense(43, activation='softmax')) 
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       401,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 43)             │         5,547 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 426,475 (1.63 MB)
#  Trainable params: 426,475 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 25s 48ms/step - accuracy: 0.5026 - loss: 1.8754 - val_accuracy: 0.9253 - val_loss: 0.2745
# Epoch 2/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - accuracy: 0.9548 - loss: 0.1796 - val_accuracy: 0.9603 - val_loss: 0.1427
# Epoch 3/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 41s 47ms/step - accuracy: 0.9750 - loss: 0.0984 - val_accuracy: 0.9602 - val_loss: 0.1547
# Epoch 4/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 41s 46ms/step - accuracy: 0.9855 - loss: 0.0591 - val_accuracy: 0.9843 - val_loss: 0.0649
# Epoch 5/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - accuracy: 0.9911 - loss: 0.0378 - val_accuracy: 0.9811 - val_loss: 0.0757
# Epoch 6/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - accuracy: 0.9942 - loss: 0.0235 - val_accuracy: 0.9782 - val_loss: 0.0888
# Epoch 7/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.9798 - loss: 0.0848 - val_accuracy: 0.9791 - val_loss: 0.0755
# Epoch 8/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 24s 49ms/step - accuracy: 0.9966 - loss: 0.0135 - val_accuracy: 0.9793 - val_loss: 0.0825
# Epoch 9/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - accuracy: 0.9974 - loss: 0.0109 - val_accuracy: 0.9855 - val_loss: 0.0630
# Epoch 10/10
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - accuracy: 0.9982 - loss: 0.0084 - val_accuracy: 0.9870 - val_loss: 0.0650

# %%
plt.imshow(img)
plt.title("ORNEK")
plt.figure(1)

# %%
import matplotlib.pyplot as plt

# Retrieve the training and validation metrics from the history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Define the range of epochs
epochs_range = range(1, len(acc) + 1)

# Plot the training and validation accuracy
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()), 1])
plt.title('Training and Validation Accuracy')

# Plot the training and validation loss
plt.subplot(2, 1, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy Loss')
plt.ylim([0, 1.0])
plt.xlabel('Epochs')
plt.title('Training and Validation Loss')

plt.show()

# %%
model.save('CAPSTONE1.h5')
